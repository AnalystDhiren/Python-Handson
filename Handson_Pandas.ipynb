# %% [markdown]
# <a href="https://colab.research.google.com/github/AnalystDhiren/Python-Handson/blob/main/Handson_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
a = [5,7,8,9]
datasets = pd.Series(a)

# %%
print(datasets)

# %%
a = [5,7,8]
datasets = pd.Series(a, index = ["No.1","No.2","No.3"])
print(datasets)

# %% [markdown]
# # DATA FRAME

# %%
data = {"Name":["Mr.X","Mr.Y","Miss Z"],"Color":["blue","Yellow","Purple"]}
dataset = pd.DataFrame(data)
print(dataset)
# Out:
#      Name   Color
# 0    Mr.X    blue
# 1    Mr.Y  Yellow
# 2  Miss Z  Purple

# %% [markdown]
# # LOADING DATA FROM A FILE

# %%
import pandas as pd

# %%
Data1 = pd.read_csv("C:\\Users\\dhirendra.p_embibe\\Desktop\\data\\Code\\dataset.csv") #inport CSV

# %%
Data1
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
print(Data1.head(5))
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
Data2 = pd.read_excel("C:\\Users\\dhirendra.p_embibe\\Desktop\\data\\Code\\dataset.xlsx") #inport excel

# %%
print(Data2.head(5))
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
#remember for CSV & Text data (pd.read_csv) will be used

# %%
Data3 = pd.read_csv("C:\\Users\\dhirendra.p_embibe\\Desktop\\data\\Code\\dataset.txt") #inport text

# %%
print(Data3.head(5))
# Out:
#   #\tName\tType 1\tType 2\tHP\tAttack\tDefense\tSp. Atk\tSp. Def\tSpeed\tGeneration\tLegendary
# 0  1\tBulbasaur\tGrass\tPoison\t45\t49\t49\t65\t6...
# 1  2\tIvysaur\tGrass\tPoison\t60\t62\t63\t80\t80\...
# 2  3\tVenusaur\tGrass\tPoison\t80\t82\t83\t100\t1...
# 3  3\tVenusaurMega Venusaur\tGrass\tPoison\t80\t1...
# 4  4\tCharmander\tFire\t\t39\t52\t43\t60\t50\t65\...

# %%
print(Data3.describe())
# Out:
#        #\tName\tType 1\tType 2\tHP\tAttack\tDefense\tSp. Atk\tSp. Def\tSpeed\tGeneration\tLegendary
# count                                                 800
# unique                                                800
# top     1\tBulbasaur\tGrass\tPoison\t45\t49\t49\t65\t6...
# freq                                                    1

# %%
print(Data2
      .describe()) #data for info
# Out:
#                 #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.000000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750   69.258750   79.001250   73.842500   72.820000   71.902500
# std    208.343798   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.000000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    184.750000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    364.500000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    539.250000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    721.000000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# ...

# %%
print(Data2.shape)  #count row and columns
# Out:
# (800, 12)

# %% [markdown]
# # DATA SLICING

# %% [raw]
# Get title columns

# %%
print(Data2.columns)
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
print(Data2["Name"])  #get the data by Gving the NAME
# Out:
# 0                  Bulbasaur
# 1                    Ivysaur
# 2                   Venusaur
# 3      VenusaurMega Venusaur
# 4                 Charmander
#                ...
# 795                  Diancie
# 796      DiancieMega Diancie
# 797      HoopaHoopa Confined
# 798       HoopaHoopa Unbound
# 799                Volcanion
# Name: Name, Length: 800, dtype: object

# %%
print(Data2[["Name","Speed"]])  #get the data by Gving the multiple title by NAME
# Out:
#                       Name  Speed
# 0                Bulbasaur     45
# 1                  Ivysaur     60
# 2                 Venusaur     80
# 3    VenusaurMega Venusaur     80
# 4               Charmander     65
# ..                     ...    ...
# 795                Diancie     50
# 796    DiancieMega Diancie    110
# 797    HoopaHoopa Confined     70
# 798     HoopaHoopa Unbound     80
# 799              Volcanion     70
#
# [800 rows x 2 columns]

# %%
print(Data2["Name"][0:20]) #get the list fo data with specific count
# Out:
# 0                     Bulbasaur
# 1                       Ivysaur
# 2                      Venusaur
# 3         VenusaurMega Venusaur
# 4                    Charmander
# 5                    Charmeleon
# 6                     Charizard
# 7     CharizardMega Charizard X
# 8     CharizardMega Charizard Y
# 9                      Squirtle
# 10                    Wartortle
# 11                    Blastoise
# 12      BlastoiseMega Blastoise
# 13                     Caterpie
# 14                      Metapod
# 15                   Butterfree
# 16                       Weedle
# 17                       Kakuna
# 18                     Beedrill
# 19        BeedrillMega Beedrill
# Name: Name, dtype: object

# %% [raw]
# ILOC - integer Location

# %%
print(Data2.iloc[6])  #get the data Row wise
# Out:
# #                     6
# Name          Charizard
# Type 1             Fire
# Type 2           Flying
# HP                   78
# Attack               84
# Defense              78
# Sp. Atk             109
# Sp. Def              85
# Speed               100
# Generation            1
# Legendary         False
# Name: 6, dtype: object

# %%
print(Data2.iloc[12
                :18])  #get the data Row from A to B wise ## between range
# Out:
#      #                     Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 12   9  BlastoiseMega Blastoise  Water     NaN  79     103      120      135
# 13  10                 Caterpie    Bug     NaN  45      30       35       20
# 14  11                  Metapod    Bug     NaN  50      20       55       25
# 15  12               Butterfree    Bug  Flying  60      45       50       90
# 16  13                   Weedle    Bug  Poison  40      35       30       20
# 17  14                   Kakuna    Bug  Poison  45      25       50       25
#
#     Sp. Def  Speed  Generation  Legendary
# 12      115     78           1      False
# 13       20     45           1      False
# 14       25     30           1      False
# 15       80     70           1      False
# 16       20     50           1      False
# 17       25     35           1      False

# %%
print(Data2.iloc[1,2])  #get the data of specific cell (1,2 means 1 row second cell)
# Out:
# Grass

# %%
for index,row in Data2.iterrows():
    print(index,row["Name"])  #get the entire data rowwise w.r.t"Name"
# Out:
# 0 Bulbasaur
# 1 Ivysaur
# 2 Venusaur
# 3 VenusaurMega Venusaur
# 4 Charmander
# 5 Charmeleon
# 6 Charizard
# 7 CharizardMega Charizard X
# 8 CharizardMega Charizard Y
# 9 Squirtle
# 10 Wartortle
# 11 Blastoise
# 12 BlastoiseMega Blastoise
# 13 Caterpie
# 14 Metapod
# 15 Butterfree
# 16 Weedle
# 17 Kakuna
# 18 Beedrill
# 19 BeedrillMega Beedrill
# 20 Pidgey
# 21 Pidgeotto
# 22 Pidgeot
# 23 PidgeotMega Pidgeot
# 24 Rattata
# 25 Raticate
# 26 Spearow
# 27 Fearow
# 28 Ekans
# 29 Arbok
# 30 Pikachu
# 31 Raichu
# 32 Sandshrew
# 33 Sandslash
# 34 Nidoran (Female)
# 35 Nidorina
# 36 Nidoqueen
# 37 Nidoran (Male)
# 38 Nidorino
# 39 Nidoking
# 40 Clefairy
# 41 Clefable
# 42 Vulpix
# 43 Ninetales
# 44 Jigglypuff
# 45 Wigglytuff
# 46 Zubat
# 47 Golbat
# 48 Oddish
# 49 Gloom
# 50 Vileplume
# 51 Paras
# 52 Parasect
# 53 Venonat
# 54 Venomoth
# 55 Diglett
# 56 Dugtrio
# 57 Meowth
# 58 Persian
# 59 Psyduck
# 60 Golduck
# 61 Mankey
# 62 Primeape
# 63 Growlithe
# 64 Arcanine
# 65 Poliwag
# ...

# %% [markdown]
# # FILTER

# %%
Filter1 = print(Data2.loc[Data2["Speed"]>70])
# Out:
#        #                       Name   Type 1  Type 2   HP  Attack  Defense  \
# 2      3                   Venusaur    Grass  Poison   80      82       83
# 3      3      VenusaurMega Venusaur    Grass  Poison   80     100      123
# 5      5                 Charmeleon     Fire     NaN   58      64       58
# 6      6                  Charizard     Fire  Flying   78      84       78
# 7      6  CharizardMega Charizard X     Fire  Dragon   78     130      111
# ..   ...                        ...      ...     ...  ...     ...      ...
# 792  716                    Xerneas    Fairy     NaN  126     131       95
# 793  717                    Yveltal     Dark  Flying  126     131       95
# 794  718           Zygarde50% Forme   Dragon  Ground  108     100      121
# 796  719        DiancieMega Diancie     Rock   Fairy   50     160      110
# 798  720         HoopaHoopa Unbound  Psychic    Dark   80     160       60
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
print(Filter1)
# Out:
# None

# %%
#fILTER Type two -

# %%
Filter2 = print(Data2.loc[Data2["Type 2"]=="Poison"])
# Out:
#        #                   Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 0      1              Bulbasaur  Grass  Poison   45      49       49       65
# 1      2                Ivysaur  Grass  Poison   60      62       63       80
# 2      3               Venusaur  Grass  Poison   80      82       83      100
# 3      3  VenusaurMega Venusaur  Grass  Poison   80     100      123      122
# 16    13                 Weedle    Bug  Poison   40      35       30       20
# 17    14                 Kakuna    Bug  Poison   45      25       50       25
# 18    15               Beedrill    Bug  Poison   65      90       40       45
# 19    15  BeedrillMega Beedrill    Bug  Poison   65     150       40       15
# 48    43                 Oddish  Grass  Poison   45      50       55       75
# 49    44                  Gloom  Grass  Poison   60      65       70       85
# 50    45              Vileplume  Grass  Poison   75      80       85      110
# ...

# %%
print(Filter2)
# Out:
# None

# %%
print(Data1.ndim)
# Out:
# 2

# %% [markdown]
# # SORTING DATA

# %%
#sort data in desending order w.e.r to "HP"

# %%
Data2.sort_values(["HP"],ascending=False)
# Out:
#        #       Name   Type 1 Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 261  242    Blissey   Normal    NaN  255      10       10       75      135
# 121  113    Chansey   Normal    NaN  250       5        5       35      105
# 217  202  Wobbuffet  Psychic    NaN  190      33       58       33       58
# 351  321    Wailord    Water    NaN  170      90       45       90       45
# 655  594  Alomomola    Water    NaN  165      75       80       40       45
# ..   ...        ...      ...    ...  ...     ...      ...      ...      ...
# 139  129   Magikarp    Water    NaN   20      10       55       15       20
# 381  349     Feebas    Water    NaN   20      15       20       10       55
# 388  355    Duskull    Ghost    NaN   20      40       90       30       90
# 55    50    Diglett   Ground    NaN   10      55       25       35       45
# 316  292   Shedinja      Bug  Ghost    1      90       45       30       30
#
#      Speed  Generation  Legendary
# ...

# %% [markdown]
# # EDIT DATA

# %%
Data2["Power"] = Data2["HP"] + Data2["Attack"]
print(Data2.head())
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Power
# 0       65     45           1      False     94
# 1       80     60           1      False    122
# 2      100     80           1      False    162
# 3      120     80           1      False    180
# 4       50     65           1      False     91

# %%
Data2
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Power
# 0         65       65     45           1      False     94
# ...

# %%
Data2 = Data2.drop(columns=["Power"])

# %%
Data2
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %% [markdown]
# # EXPORT CSV

# %%
Data2.to_csv("C:\\Users\\dhirendra.p_embibe\\Desktop\\\dataset.csv")  #EXPORT THE FILERED DATA

# %% [markdown]
# # Checking Null values

# %%
Data2.isna().any() #CHECK entire data if there is any NaN/Null/Blank columns value
# Out:
# #             False
# Name          False
# Type 1        False
# Type 2        False
# HP            False
# Attack        False
# Defense       False
# Sp. Atk       False
# Sp. Def       False
# Speed         False
# Generation    False
# Legendary     False
# dtype: bool

# %% [markdown]
# # removing The Null Values

# %%
Data2 = Data2[Data2["Type 2"].notna()]

# %%
Data2.isna().any() #CHECK entire data if there is any NaN/Null/Blank columns value
# Out:
# #             False
# Name          False
# Type 1        False
# Type 2        False
# HP            False
# Attack        False
# Defense       False
# Sp. Atk       False
# Sp. Def       False
# Speed         False
# Generation    False
# Legendary     False
# dtype: bool

# %% [markdown]
# # Replacin the NULL values with Data (Mean of that coulumn)

# %%
FillMean = Data2["Speed"].fillna(Data2["Speed"].mean())

# %%
FillMean
# Out:
# 0       45
# 1       60
# 2       80
# 3       80
# 6      100
#       ...
# 795     50
# 796    110
# 797     70
# 798     80
# 799     70
# Name: Speed, Length: 414, dtype: int64

# %%
print(Data2)
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 6      6              Charizard     Fire  Flying  78      84       78
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %% [markdown]
# # Replace number 1(Integer) with Name(String) one in Generation coloumn

# %%
print(Data2.head())
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 6  6              Charizard   Fire  Flying  78      84       78      109
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 6       85    100           1      False

# %%
Generationconv =  set(Data2['Generation'])

# %%
Data2['Generation'] = Data2['Generation'].map({1:"one", 2: "two", 3:"three", 4:"four", 5:"five", 6:"six"}).astype(str)
print(Data2.head())
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 6  6              Charizard   Fire  Flying  78      84       78      109
#
#    Sp. Def  Speed Generation  Legendary
# 0       65     45        one      False
# 1       80     60        one      False
# 2      100     80        one      False
# 3      120     80        one      False
# 6       85    100        one      False
# C:\Users\DHIREN~1.P_E\AppData\Local\Temp/ipykernel_4940/4036325375.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...
